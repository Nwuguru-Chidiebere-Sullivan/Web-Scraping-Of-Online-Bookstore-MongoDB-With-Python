# %% [markdown]
# # Web Scraping Of Online Bookstore & MongoDB With Python
#
# ### Context:
# The data for this project was scraped from the 'Books to Scrape' website using Python. The scraping was done across the 50 pages of the website.
#
# ### Aim:
# The aim of this project is to scrape data from a website of about 50 pages, transform the data into a CSV file, insert the CSV file into a database using pymongo of MongoDB, and thereafter, retrieve the collection from the databse and read it into a DataFrame which can be analysed, manipulated, and processed for Data Science works.

# %% [markdown]
#  ![](Pictures/web-scraping.webp)

# %% [markdown]
# ### Importation of the necessary module for the project

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# #### Let's get the url address of the fisrt page of the website we wish to scrape data from:

# %%
url = "http://books.toscrape.com/catalogue/page-1.html"

# %% [markdown]
# #### Let's get a response from the address and then obtain the content of the response. We can thereafter, parse it into html using BeautifulSoup

# %%
response = requests.get(url)
response = response.content
soup = BeautifulSoup(response, 'html.parser')

# %% [markdown]
# #### Let's find the ordinary list(ol) that contains the article in which the contents of the data we wish to scrape are contained in.

# %%
ol = soup.find('ol')
articles = ol.find_all('article', class_ = 'product_pod')

# %% [markdown]
# #### Now, let's performthe above process across the 50 pages of the website starting from the first page.

# %%
books = []
for i in range(1,51):
    url = f"http://books.toscrape.com/catalogue/page-{i}.html"
    response = requests.get(url)
    response = response.content
    soup = BeautifulSoup(response, 'html.parser')
    ol = soup.find('ol')
    articles = ol.find_all('article', class_ = 'product_pod')

    
    for article in articles:
        image = article.find('img')
        title = image.attrs['alt']
        star_rating = article.find('p')
        star_rating = star_rating['class'][1]
        price = article.find('p', class_ = 'price_color').text
        price = float(price[1:])
        books.append([title, price, star_rating])

# %% [markdown]
# #### Having scrapped our desired date from the website pages, let's now create a pandas DataFrame from it, and thereafter, make a csv file from it.

# %%
df = pd.DataFrame(books, columns=["Title", "Price", "Star Rating"])
df.to_csv("Books.csv")

# %%
#let's read the csv file and get a view of it
books_df = pd.read_csv("Desktop/CSV Files/Books.csv")
books_df.head()
# Out:
#    Unnamed: 0                                  Title  Price Star Rating
# 0           0                   A Light in the Attic  51.77       Three
# 1           1                     Tipping the Velvet  53.74         One
# 2           2                             Soumission  50.10         One
# 3           3                          Sharp Objects  47.82        Four
# 4           4  Sapiens: A Brief History of Humankind  54.23        Five

# %% [markdown]
# ## Inserting CSV file into MongoDB

# %% [markdown]
# ### Let's import the libraries we will use to insert the Books.csv file into MongoDB

# %%
import pandas as pd
import pymongo
import json

# %%
#let's create a client
client = pymongo.MongoClient('mongodb://localhost:27017')

# %%
#let's read our csv file, view the first the fisrt 5 rows and the shape of the dataframe
books_df = pd.read_csv('Books.csv')
print(f'The shape of books_df is:{books_df.shape}')
books_df.head()
# Out:
# The shape of books_df is:(1000, 4)
#    Unnamed: 0                                  Title  Price Star Rating
# 0           0                   A Light in the Attic  51.77       Three
# 1           1                     Tipping the Velvet  53.74         One
# 2           2                             Soumission  50.10         One
# 3           3                          Sharp Objects  47.82        Four
# 4           4  Sapiens: A Brief History of Humankind  54.23        Five

# %%
#let's drop the unimportant column
books_df.drop(columns='Unnamed: 0', inplace=True)
books_df.tail()
# Out:
#                                                  Title  Price Star Rating
# 995  Alice in Wonderland (Alice's Adventures in Won...  55.53         One
# 996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)  57.06        Four
# 997  A Spy's Devotion (The Regency Spies of London #1)  16.97        Five
# 998                1st to Die (Women's Murder Club #1)  53.98         One
# 999                 1,000 Places to See Before You Die  26.08        Five

# %%
#rename the Star Rating column
books_df.rename(columns = {'Star Rating':'Star_rating'}, inplace=True)
books_df.head()
# Out:
#                                    Title  Price Star_rating
# 0                   A Light in the Attic  51.77       Three
# 1                     Tipping the Velvet  53.74         One
# 2                             Soumission  50.10         One
# 3                          Sharp Objects  47.82        Four
# 4  Sapiens: A Brief History of Humankind  54.23        Five

# %% [markdown]
# #### Let's read our dataframe into a json format which is the format of storing data in MongoDB:

# %%
data = books_df.to_dict(orient = 'records')
print(data)
# Out:
# [{'Title': 'A Light in the Attic', 'Price': 51.77, 'Star_rating': 'Three'}, {'Title': 'Tipping the Velvet', 'Price': 53.74, 'Star_rating': 'One'}, {'Title': 'Soumission', 'Price': 50.1, 'Star_rating': 'One'}, {'Title': 'Sharp Objects', 'Price': 47.82, 'Star_rating': 'Four'}, {'Title': 'Sapiens: A Brief History of Humankind', 'Price': 54.23, 'Star_rating': 'Five'}, {'Title': 'The Requiem Red', 'Price': 22.65, 'Star_rating': 'One'}, {'Title': 'The Dirty Little Secrets of Getting Your Dream Job', 'Price': 33.34, 'Star_rating': 'Four'}, {'Title': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', 'Price': 17.93, 'Star_rating': 'Three'}, {'Title': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'Price': 22.6, 'Star_rating': 'Four'}, {'Title': 'The Black Maria', 'Price': 52.15, 'Star_rating': 'One'}, {'Title': 'Starving Hearts (Triangular Trade Trilogy, #1)', 'Price': 13.99, 'Star_rating': 'Two'}, {'Title': "Shakespeare's Sonnets", 'Price': 20.66, 'Star_rating': 'Four'}, {'Title': 'Set Me Free', 'Price': 17.46, 'Star_rating': 'Five'}, {'Title': "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 'Price': 52.29, 'Star_rating': 'Five'}, {'Title': 'Rip it Up and Start Again', 'Price': 35.02, 'Star_rating': 'Five'}, {'Title': 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991', 'Price': 57.25, 'Star_rating': 'Three'}, {'Title': 'Olio', 'Price': 23.88, 'Star_rating': 'One'}, {'Title': 'Mesaerion: The Best Science Fiction Stories 1800-1849', 'Price': 37.59, 'Star_rating': 'One'}, {'Title': 'Libertarianism for Beginners', 'Price': 51.33, 'Star_rating': 'Two'}, {'Title': "It's Only the Himalayas", 'Price': 45.17, 'Star_rating': 'Two'}, {'Title': 'In Her Wake', 'Price': 12.84, 'Star_rating': 'One'}, {'Title': 'How Music Works', 'Price': 37.32, 'Star_rating': 'Two'}, {'Title': 'Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More', 'Price': 30.52, 'Star_rating': 'Three'}, {'Title': 'Chase Me (Paris Nights #2)', 'Price': 25.27, 'Star_rating': 'Five'}, {'Title': 'Black Dust', 'Price': 34.53, 'Star_rating': 'Five'}, {'Title': 'Birdsong: A Story in Pictures', 'Price': 54.64, 'Star_rating': 'Three'}, {'Title': "America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana", 'Price': 22.5, 'Star_rating': 'Three'}, {'Title': 'Aladdin and His Wonderful Lamp', 'Price': 53.13, 'Star_rating': 'Three'}, {'Title': 'Worlds Elsewhere: Journeys Around Shakespeare’s Globe', 'Price': 40.3, 'Star_rating': 'Five'}, {'Title': 'Wall and Piece', 'Price': 44.18, 'Star_rating': 'Four'}, {'Title': 'The Four Agreements: A Practical Guide to Personal Freedom', 'Price': 17.66, 'Star_rating': 'Five'}, {'Title': 'The Five Love Languages: How to Express Heartfelt Commitment to Your Mate', 'Price': 31.05, 'Star_rating': 'Three'}, {'Title': 'The Elephant Tree', 'Price': 23.82, 'Star_rating': 'Five'}, {'Title': 'The Bear and the Piano', 'Price': 36.89, 'Star_rating': 'One'}, {'Title': "Sophie's World", 'Price': 15.94, 'Star_rating': 'Five'}, {'Title': 'Penny Maybe', 'Price': 33.29, 'Star_rating': 'Three'}, {'Title': 'Maude (1883-1993):She Grew Up with the country', 'Price': 18.02, 'Star_rating': 'Two'}, {'Title': 'In a Dark, Dark Wood', 'Price': 19.63, 'Star_rating': 'One'}, {'Title': 'Behind Closed Doors', 'Price': 52.22, 'Star_rating': 'Four'}, {'Title': "You can't bury them all: Poems", 'Price': 33.63, 'Star_rating': 'Two'}, {'Title': 'Slow States of Collapse: Poems', 'Price': 57.31, 'Star_rating': 'Three'}, {'Title': 'Reasons to Stay Alive', 'Price': 26.41, 'Star_rating': 'Two'}, {'Title': 'Private Paris (Private #10)', 'Price': 47.61, 'Star_rating': 'Five'}, {'Title': '#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.', 'Price': 23.11, 'Star_rating': 'Five'}, {' ...

# %% [markdown]
# **We can see now that our data is now stored in dictionary(json) format.**

# %% [markdown]
# #### Let's create a database into which we will store our data

# %%
db = client['WebScraping']
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'WebScraping')

# %% [markdown]
# #### Let's insert our collection(table) into our newly created database:

# %%
db.Books.insert_many(data)

# %% [markdown]
# **Conclusion:**
# We have successfully created our database and collection with python using pymongo

# %% [markdown]
# ## Load Collection(table) From MongoDB To Python

# %%
#let's intall and instantiate PrettyPrinter
from pprint import PrettyPrinter
pp = PrettyPrinter(indent=2)

# %%
#let's print our database
pp.pprint(list(client.list_databases()))
# Out:
# [ {'empty': False, 'name': 'WebScraping', 'sizeOnDisk': 94208},
#   {'empty': False, 'name': 'admin', 'sizeOnDisk': 40960},
#   {'empty': False, 'name': 'config', 'sizeOnDisk': 110592},
#   {'empty': False, 'name': 'local', 'sizeOnDisk': 81920},
#   {'empty': False, 'name': 'players', 'sizeOnDisk': 81920}]

# %%
#let's pull our database
db = client['WebScraping']

#print the list of collection available in db
for c in db.list_collections():
    print(c['name'])
# Out:
# Books

# %%
#let define our collection
mycollection = db['Books']
mycollection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'WebScraping'), 'Books')

# %%
#let's see how many documents are in mycollection
mycollection.count_documents({})
# Out:
# 1000

# %%
#let's print our first record
first_record = mycollection.find_one({})
pp.pprint(first_record)
# Out:
# { 'Price': 51.77,
#   'Star_rating': 'Three',
#   'Title': 'A Light in the Attic',
#   '_id': ObjectId('6495541fa0480a0e669ef5eb')}

# %%
#let's print all records
all_records = mycollection.find({})
pp.pprint(all_records)
# Out:
# <pymongo.cursor.Cursor object at 0x000002981BEF0430>

# %%
#To be able to access all the records, we will have to run a for loop on the cursor object which we got as the output
for row in all_records:
    pp.pprint(row)
# Out:
# { 'Price': 51.77,
#   'Star_rating': 'Three',
#   'Title': 'A Light in the Attic',
#   '_id': ObjectId('6495541fa0480a0e669ef5eb')}
# { 'Price': 53.74,
#   'Star_rating': 'One',
#   'Title': 'Tipping the Velvet',
#   '_id': ObjectId('6495541fa0480a0e669ef5ec')}
# { 'Price': 50.1,
#   'Star_rating': 'One',
#   'Title': 'Soumission',
#   '_id': ObjectId('6495541fa0480a0e669ef5ed')}
# { 'Price': 47.82,
#   'Star_rating': 'Four',
#   'Title': 'Sharp Objects',
#   '_id': ObjectId('6495541fa0480a0e669ef5ee')}
# { 'Price': 54.23,
#   'Star_rating': 'Five',
#   'Title': 'Sapiens: A Brief History of Humankind',
#   '_id': ObjectId('6495541fa0480a0e669ef5ef')}
# { 'Price': 22.65,
#   'Star_rating': 'One',
#   'Title': 'The Requiem Red',
#   '_id': ObjectId('6495541fa0480a0e669ef5f0')}
# { 'Price': 33.34,
#   'Star_rating': 'Four',
#   'Title': 'The Dirty Little Secrets of Getting Your Dream Job',
#   '_id': ObjectId('6495541fa0480a0e669ef5f1')}
# { 'Price': 17.93,
#   'Star_rating': 'Three',
#   'Title': 'The Coming Woman: A Novel Based on the Life of the Infamous '
#            'Feminist, Victoria Woodhull',
#   '_id': ObjectId('6495541fa0480a0e669ef5f2')}
# { 'Price': 22.6,
#   'Star_rating': 'Four',
#   'Title': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold '
#            'at the 1936 Berlin Olympics',
#   '_id': ObjectId('6495541fa0480a0e669ef5f3')}
# { 'Price': 52.15,
#   'Star_rating': 'One',
#   'Title': 'The Black Maria',
#   '_id': ObjectId('6495541fa0480a0e669ef5f4')}
# { 'Price': 13.99,
#   'Star_rating': 'Two',
#   'Title': 'Starving Hearts (Triangular Trade Trilogy, #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef5f5')}
# { 'Price': 20.66,
#   'Star_rating': 'Four',
#   'Title': "Shakespeare's Sonnets",
#   '_id': ObjectId('6495541fa0480a0e669ef5f6')}
# { 'Price': 17.46,
#   'Star_rating': 'Five',
#   'Title': 'Set Me Free',
#   '_id': ObjectId('6495541fa0480a0e669ef5f7')}
# { 'Price': 52.29,
#   'Star_rating': 'Five',
#   'Title': "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)",
#   '_id': ObjectId('6495541fa0480a0e669ef5f8')}
# { 'Price': 35.02,
#   'Star_rating': 'Five',
#   'Title': 'Rip it Up and Start Again',
#   '_id': ObjectId('6495541fa0480a0e669ef5f9')}
# { 'Price': 57.25,
#   'Star_rating': 'Three',
#   'Title': 'Our Band Could Be Your Life: Scenes from the American Indie '
#            'Underground, 1981-1991',
#   '_id': ObjectId('6495541fa0480a0e669ef5fa')}
# { 'Price': 23.88,
#   'Star_rating': 'One',
#   'Title': 'Olio',
#   '_id': ObjectId('6495541fa0480a0e669ef5fb')}
# { 'Price': 37.59,
#   'Star_rating': 'One',
#   'Title': 'Mesaerion: The Best Science Fiction Stories 1800-1849',
#   '_id': ObjectId('6495541fa0480a0e669ef5fc')}
# { 'Price': 51.33,
#   'Star_rating': 'Two',
#   'Title': 'Libertarianism for Beginners',
#   '_id': ObjectId('6495541fa0480a0e669ef5fd')}
# { 'Price': 45.17,
#   'Star_rating': 'Two',
#   'Title': "It's Only the Himalayas",
#   '_id': ObjectId('6495541fa0480a0e669ef5fe')}
# { 'Price': 12.84,
#   'Star_rating': 'One',
#   'Title': 'In Her Wake',
#   '_id': ObjectId('6495541fa0480a0e669ef5ff')}
# { 'Price': 37.32,
#   'Star_rating': 'Two',
#   'Title': 'How Music Works',
#   '_id': ObjectId('6495541fa0480a0e669ef600')}
# { 'Price': 30.52,
#   'Star_rating': 'Three',
#   'Title': 'Foolproof Preserving: A Guide to Small Batch Jams, Jellies, '
#            'Pickles, Condiments, and More: A Foolproof Guide to Making Small '
#            'Batch Jams, Jellies, Pickles, Condiments, and More',
#   '_id': ObjectId('6495541fa0480a0e669ef601')}
# { 'Price': 25.27,
#   'Star_rating': 'Five',
#   'Title': 'Chase Me (Paris Nights #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef602')}
# { 'Price': 34.53,
#   'Star_rating': 'Five',
#   'Title': 'Black Dust',
#   '_id': ObjectId('6495541fa0480a0e669ef603')}
# { 'Price': 54.64,
#   'Star_rating': 'Three',
#   'Title': 'Birdsong: A Story in Pictures',
#   '_id': ObjectId('6495541fa0480a0e669ef604')}
# { 'Price': 22.5,
#   'Star_rating': 'Three',
#   'Title': "America's Cradle of Quarterbacks: Western Pennsylvania's Football "
#            'Factory from Johnny Unitas to Joe Montana',
#   '_id': ObjectId('6495541fa0480a0e669ef605')}
# { 'Price': 53.13,
#   'Star_rating': 'Three',
#   'Title': 'Aladdin and His Wonderful Lamp',
#   '_id': ObjectId('6495541fa0480a0e669ef606')}
# { 'Price': 40.3,
#   'Star_rating': 'Five',
#   'Title': 'Worlds Elsewhere: Journeys Around Shakespeare’s Globe',
#   '_id': ObjectId('6495541fa0480a0e669ef607')}
# { 'Price': 44.18,
#   'Star_rating': 'Four',
#   'Title': 'Wall and Piece',
#   '_id': ObjectId('6495541fa0480a0e669ef608')}
# { 'Price': 17.66,
#   'Star_rating': 'Five',
#   'Title': 'The Four Agreements: A Practical Guide to Personal Freedom',
#   '_id': ObjectId('6495541fa0480a0e669ef609')}
# { 'Price': 31.05,
#   'Star_rating': 'Three',
#   'Title': 'The Five Love Languages: How to Express Heartfelt Commitment to '
#            'Your Mate',
#   '_id': ObjectId('6495541fa0480a0e669ef60a')}
# { 'Price': 23.82,
#   'Star_rating': 'Five',
#   'Title': 'The Elephant Tree',
#   '_id': ObjectId('6495541fa0480a0e669ef60b')}
# { 'Price': 36.89,
#   'Star_rating': 'One',
#   'Title': 'The Bear and the Piano',
#   '_id': ObjectId('6495541fa0480a0e669ef60c')}
# { 'Price': 15.94,
#   'Star_rating': 'Five',
#   'Title': "Sophie's World",
#   '_id': ObjectId('6495541fa0480a0e669ef60d')}
# { 'Price': 33.29,
#   'Star_rating': 'Three',
#   'Title': 'Penny Maybe',
#   '_id': ObjectId('6495541fa0480a0e669ef60e')}
# { 'Price': 18.02,
#   'Star_rating': 'Two',
#   'Title': 'Maude (1883-1993):She Grew Up with the country',
#   '_id': ObjectId('6495541fa0480a0e669ef60f')}
# { 'Price': 19.63,
#   'Star_rating': 'One',
#   'Title': 'In a Dark, Dark Wood',
#   '_id': ObjectId('6495541fa0480a0e669ef610')}
# { 'Price': 52.22,
#   'Star_rating': 'Four',
#   'Title': 'Behind Closed Doors',
#   '_id': ObjectId('6495541fa0480a0e669ef611')}
# { 'Price': 33.63,
#   'Star_rating': 'Two',
#   'Title': "You can't bury them all: Poems",
#   '_id': ObjectId('6495541fa0480a0e669ef612')}
# { 'Price': 57.31,
#   'Star_rating': 'Three',
#   'Title': 'Slow States of Collapse: Poems',
#   '_id': ObjectId('6495541fa0480a0e669ef613')}
# { 'Price': 26.41,
#   'Star_rating': 'Two',
#   'Title': 'Reasons to Stay Alive',
#   '_id': ObjectId('6495541fa0480a0e669ef614')}
# { 'Price': 47.61,
#   'Star_rating': 'Five',
#   'Title': 'Private Paris (Private #10)',
#   '_id': ObjectId('6495541fa0480a0e669ef615')}
# { 'Price': 23.11,
#   'Star_rating': 'Five',
#   'Title': '#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.',
#   '_id': ObjectId('6495541fa0480a0e669ef616')}
# { 'Price': 45.07,
#   'Star_rating': 'Two',
#   'Title': 'Without Borders (Wanderlove #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef617')}
# { 'Price': 31.77,
#   'Star_rating': 'One',
#   'Title': 'When We Collided',
#   '_id': ObjectId('6495541fa0480a0e669ef618')}
# { 'Price': 50.27,
#   'Star_rating': 'Five',
#   'Title': 'We Love You, Charlie Freeman',
#   '_id': ObjectId('6495541fa0480a0e669ef619')}
# { 'Price': 14.27,
#   'Star_rating': 'Four',
#   'Title': 'Untitled Collection: Sabbath Poems 2014',
#   '_id': ObjectId('6495541fa0480a0e669ef61a')}
# { 'Price': 44.18,
#   'Star_rating': 'Four',
#   'Title': 'Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails '
#            '& Other Wonders of the Urban Wilderness',
#   '_id': ObjectId('6495541fa0480a0e669ef61b')}
# { 'Price': 18.78,
#   'Star_rating': 'Three',
#   'Title': 'Unicorn Tracks',
#   '_id': ObjectId('6495541fa0480a0e669ef61c')}
# { 'Price': 25.52,
#   'Star_rating': 'One',
#   'Title': 'Unbound: How Eight Technologies Made Us Human, Transformed '
#            'Society, and Brought Our World to the Brink',
#   '_id': ObjectId('6495541fa0480a0e669ef61d')}
# { 'Price': 16.28,
#   'Star_rating': 'One',
#   'Title': 'Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef61e')}
# { 'Price': 31.12,
#   'Star_rating': 'Three',
#   'Title': 'Throwing Rocks at the Google Bus: How Growth Became the Enemy of '
#            'Prosperity',
#   '_id': ObjectId('6495541fa0480a0e669ef61f')}
# { 'Price': 19.49,
#   'Star_rating': 'Four',
#   'Title': 'This One Summer',
#   '_id': ObjectId('6495541fa0480a0e669ef620')}
# { 'Price': 17.27,
#   'Star_rating': 'Five',
#   'Title': 'Thirst',
#   '_id': ObjectId('6495541fa0480a0e669ef621')}
# { 'Price': 19.09,
#   'Star_rating': 'One',
#   'Title': 'The Torch Is Passed: A Harding Family Story',
#   '_id': ObjectId('6495541fa0480a0e669ef622')}
# { 'Price': 56.13,
#   'Star_rating': 'One',
#   'Title': 'The Secret of Dreadwillow Carse',
#   '_id': ObjectId('6495541fa0480a0e669ef623')}
# { 'Price': 56.41,
#   'Star_rating': 'One',
#   'Title': 'The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer '
#            'Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!',
#   '_id': ObjectId('6495541fa0480a0e669ef624')}
# { 'Price': 56.5,
#   'Star_rating': 'Four',
#   'Title': 'The Past Never Ends',
#   '_id': ObjectId('6495541fa0480a0e669ef625')}
# { 'Price': 45.22,
#   'Star_rating': 'Three',
#   'Title': 'The Natural History of Us (The Fine Art of Pretending #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef626')}
# { 'Price': 38.16,
#   'Star_rating': 'Four',
#   'Title': 'The Nameless City (The Nameless City #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef627')}
# { 'Price': 54.11,
#   'Star_rating': 'Three',
#   'Title': 'The Murder That Never Was (Forensic Instincts #5)',
#   '_id': ObjectId('6495541fa0480a0e669ef628')}
# { 'Price': 42.96,
#   'Star_rating': 'Four',
#   'Title': "The Most Perfect Thing: Inside (and Outside) a Bird's Egg",
#   '_id': ObjectId('6495541fa0480a0e669ef629')}
# { 'Price': 23.89,
#   'Star_rating': 'Four',
#   'Title': 'The Mindfulness and Acceptance Workbook for Anxiety: A Guide to '
#            'Breaking Free from Anxiety, Phobias, and Worry Using Acceptance '
#            'and Commitment Therapy',
#   '_id': ObjectId('6495541fa0480a0e669ef62a')}
# { 'Price': 16.77,
#   'Star_rating': 'Three',
#   'Title': 'The Life-Changing Magic of Tidying Up: The Japanese Art of '
#            'Decluttering and Organizing',
#   '_id': ObjectId('6495541fa0480a0e669ef62b')}
# { 'Price': 20.59,
#   'Star_rating': 'Five',
#   'Title': 'The Inefficiency Assassin: Time Management Tactics for Working '
#            'Smarter, Not Longer',
#   '_id': ObjectId('6495541fa0480a0e669ef62c')}
# { 'Price': 37.13,
#   'Star_rating': 'One',
#   'Title': 'The Gutsy Girl: Escapades for Your Life of Epic Adventure',
#   '_id': ObjectId('6495541fa0480a0e669ef62d')}
# { 'Price': 56.06,
#   'Star_rating': 'One',
#   'Title': 'The Electric Pencil: Drawings from Inside State Hospital No. 3',
#   '_id': ObjectId('6495541fa0480a0e669ef62e')}
# { 'Price': 58.11,
#   'Star_rating': 'Four',
#   'Title': 'The Death of Humanity: and the Case for Life',
#   '_id': ObjectId('6495541fa0480a0e669ef62f')}
# { 'Price': 49.05,
#   'Star_rating': 'Three',
#   'Title': 'The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and '
#            'Focus, Upgrade Your Life',
#   '_id': ObjectId('6495541fa0480a0e669ef630')}
# { 'Price': 40.76,
#   'Star_rating': 'Three',
#   'Title': 'The Art Forger',
#   '_id': ObjectId('6495541fa0480a0e669ef631')}
# { 'Price': 19.73,
#   'Star_rating': 'One',
#   'Title': 'The Age of Genius: The Seventeenth Century and the Birth of the '
#            'Modern Mind',
#   '_id': ObjectId('6495541fa0480a0e669ef632')}
# { 'Price': 32.24,
#   'Star_rating': 'Five',
#   'Title': "The Activist's Tao Te Ching: Ancient Advice for a Modern "
#            'Revolution',
#   '_id': ObjectId('6495541fa0480a0e669ef633')}
# { 'Price': 41.83,
#   'Star_rating': 'Four',
#   'Title': 'Spark Joy: An Illustrated Master Class on the Art of Organizing '
#            'and Tidying Up',
#   '_id': ObjectId('6495541fa0480a0e669ef634')}
# { 'Price': 39.58,
#   'Star_rating': 'Two',
#   'Title': 'Soul Reader',
#   '_id': ObjectId('6495541fa0480a0e669ef635')}
# { 'Price': 39.25,
#   'Star_rating': 'Two',
#   'Title': 'Security',
#   '_id': ObjectId('6495541fa0480a0e669ef636')}
# { 'Price': 25.02,
#   'Star_rating': 'Three',
#   'Title': 'Saga, Volume 6 (Saga (Collected Editions) #6)',
#   '_id': ObjectId('6495541fa0480a0e669ef637')}
# { 'Price': 51.04,
#   'Star_rating': 'Two',
#   'Title': 'Saga, Volume 5 (Saga (Collected Editions) #5)',
#   '_id': ObjectId('6495541fa0480a0e669ef638')}
# { 'Price': 19.83,
#   'Star_rating': 'Two',
#   'Title': 'Reskilling America: Learning to Labor in the Twenty-First Century',
#   '_id': ObjectId('6495541fa0480a0e669ef639')}
# { 'Price': 50.4,
#   'Star_rating': 'Three',
#   'Title': 'Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) '
#            '#11-15)',
#   '_id': ObjectId('6495541fa0480a0e669ef63a')}
# { 'Price': 13.61,
#   'Star_rating': 'Five',
#   'Title': 'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish '
#            '2-in-1 Omnibus #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef63b')}
# { 'Price': 13.34,
#   'Star_rating': 'Five',
#   'Title': 'Princess Between Worlds (Wide-Awake Princess #5)',
#   '_id': ObjectId('6495541fa0480a0e669ef63c')}
# { 'Price': 18.97,
#   'Star_rating': 'One',
#   'Title': 'Pop Gun War, Volume 1: Gift',
#   '_id': ObjectId('6495541fa0480a0e669ef63d')}
# { 'Price': 36.28,
#   'Star_rating': 'Two',
#   'Title': 'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom '
#            'Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes '
#            'in the Annals of American Politics',
#   '_id': ObjectId('6495541fa0480a0e669ef63e')}
# { 'Price': 10.16,
#   'Star_rating': 'Three',
#   'Title': 'Patience',
#   '_id': ObjectId('6495541fa0480a0e669ef63f')}
# { 'Price': 15.44,
#   'Star_rating': 'Four',
#   'Title': 'Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef640')}
# { 'Price': 48.41,
#   'Star_rating': 'One',
#   'Title': 'orange: The Complete Collection 1 (orange: The Complete Collection '
#            '#1)',
#   '_id': ObjectId('6495541fa0480a0e669ef641')}
# { 'Price': 46.35,
#   'Star_rating': 'One',
#   'Title': 'Online Marketing for Busy Authors: A Step-By-Step Guide',
#   '_id': ObjectId('6495541fa0480a0e669ef642')}
# { 'Price': 14.07,
#   'Star_rating': 'Three',
#   'Title': 'On a Midnight Clear',
#   '_id': ObjectId('6495541fa0480a0e669ef643')}
# { 'Price': 14.86,
#   'Star_rating': 'Two',
#   'Title': 'Obsidian (Lux #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef644')}
# { 'Price': 33.37,
#   'Star_rating': 'Two',
#   'Title': 'My Paris Kitchen: Recipes and Stories',
#   '_id': ObjectId('6495541fa0480a0e669ef645')}
# { 'Price': 56.4,
#   'Star_rating': 'Two',
#   'Title': 'Masks and Shadows',
#   '_id': ObjectId('6495541fa0480a0e669ef646')}
# { 'Price': 14.02,
#   'Star_rating': 'Four',
#   'Title': 'Mama Tried: Traditional Italian Cooking for the Screwed, Crude, '
#            'Vegan, and Tattooed',
#   '_id': ObjectId('6495541fa0480a0e669ef647')}
# { 'Price': 46.91,
#   'Star_rating': 'Two',
#   'Title': 'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)',
#   '_id': ObjectId('6495541fa0480a0e669ef648')}
# { 'Price': 45.61,
#   'Star_rating': 'Three',
#   'Title': 'Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)',
#   '_id': ObjectId('6495541fa0480a0e669ef649')}
# { 'Price': 19.92,
#   'Star_rating': 'Two',
#   'Title': 'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)',
#   '_id': ObjectId('6495541fa0480a0e669ef64a')}
# { 'Price': 40.11,
#   'Star_rating': 'One',
#   'Title': 'Layered: Baking, Building, and Styling Spectacular Cakes',
#   '_id': ObjectId('6495541fa0480a0e669ef64b')}
# { 'Price': 53.9,
#   'Star_rating': 'Two',
#   'Title': 'Judo: Seven Steps to Black Belt (an Introductory Guide for '
#            'Beginners)',
#   '_id': ObjectId('6495541fa0480a0e669ef64c')}
# { 'Price': 35.67,
#   'Star_rating': 'Five',
#   'Title': 'Join',
#   '_id': ObjectId('6495541fa0480a0e669ef64d')}
# { 'Price': 22.0,
#   'Star_rating': 'Four',
#   'Title': 'In the Country We Love: My Family Divided',
#   '_id': ObjectId('6495541fa0480a0e669ef64e')}
# { 'Price': 57.36,
#   'Star_rating': 'Five',
#   'Title': 'Immunity: How Elie Metchnikoff Changed the Course of Modern '
#            'Medicine',
#   '_id': ObjectId('6495541fa0480a0e669ef64f')}
# { 'Price': 29.17,
#   'Star_rating': 'Two',
#   'Title': 'I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland '
#            '(Compilations) #1-5)',
#   '_id': ObjectId('6495541fa0480a0e669ef650')}
# { 'Price': 54.63,
#   'Star_rating': 'Three',
#   'Title': 'I am a Hero Omnibus Volume 1',
#   '_id': ObjectId('6495541fa0480a0e669ef651')}
# { 'Price': 46.03,
#   'Star_rating': 'One',
#   'Title': 'How to Be Miserable: 40 Strategies You Already Use',
#   '_id': ObjectId('6495541fa0480a0e669ef652')}
# { 'Price': 33.97,
#   'Star_rating': 'One',
#   'Title': 'Her Backup Boyfriend (The Sorensen Family #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef653')}
# { 'Price': 22.11,
#   'Star_rating': 'Two',
#   'Title': 'Giant Days, Vol. 2 (Giant Days #5-8)',
#   '_id': ObjectId('6495541fa0480a0e669ef654')}
# { 'Price': 29.69,
#   'Star_rating': 'Three',
#   'Title': 'Forever and Forever: The Courtship of Henry Longfellow and Fanny '
#            'Appleton',
#   '_id': ObjectId('6495541fa0480a0e669ef655')}
# { 'Price': 15.97,
#   'Star_rating': 'Four',
#   'Title': 'First and First (Five Boroughs #3)',
#   '_id': ObjectId('6495541fa0480a0e669ef656')}
# { 'Price': 21.96,
#   'Star_rating': 'One',
#   'Title': 'Fifty Shades Darker (Fifty Shades #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef657')}
# { 'Price': 54.35,
#   'Star_rating': 'Two',
#   'Title': 'Everydata: The Misinformation Hidden in the Little Data You '
#            'Consume Every Day',
#   '_id': ObjectId('6495541fa0480a0e669ef658')}
# { 'Price': 37.97,
#   'Star_rating': 'Two',
#   'Title': "Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's "
#            'Greatest Zen Master',
#   '_id': ObjectId('6495541fa0480a0e669ef659')}
# { 'Price': 51.99,
#   'Star_rating': 'Four',
#   'Title': 'Danganronpa Volume 1',
#   '_id': ObjectId('6495541fa0480a0e669ef65a')}
# { 'Price': 43.29,
#   'Star_rating': 'Three',
#   'Title': 'Crown of Midnight (Throne of Glass #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef65b')}
# { 'Price': 36.72,
#   'Star_rating': 'Four',
#   'Title': 'Codename Baboushka, Volume 1: The Conclave of Death',
#   '_id': ObjectId('6495541fa0480a0e669ef65c')}
# { 'Price': 17.08,
#   'Star_rating': 'Four',
#   'Title': 'Camp Midnight',
#   '_id': ObjectId('6495541fa0480a0e669ef65d')}
# { 'Price': 29.14,
#   'Star_rating': 'Five',
#   'Title': 'Call the Nurse: True Stories of a Country Nurse on a Scottish Isle',
#   '_id': ObjectId('6495541fa0480a0e669ef65e')}
# { 'Price': 28.81,
#   'Star_rating': 'Three',
#   'Title': 'Burning',
#   '_id': ObjectId('6495541fa0480a0e669ef65f')}
# { 'Price': 49.46,
#   'Star_rating': 'Two',
#   'Title': 'Bossypants',
#   '_id': ObjectId('6495541fa0480a0e669ef660')}
# { 'Price': 37.92,
#   'Star_rating': 'Two',
#   'Title': 'Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet '
#            '(Collected Editions))',
#   '_id': ObjectId('6495541fa0480a0e669ef661')}
# { 'Price': 28.09,
#   'Star_rating': 'Two',
#   'Title': 'Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and '
#            'Shadow #3)',
#   '_id': ObjectId('6495541fa0480a0e669ef662')}
# { 'Price': 30.81,
#   'Star_rating': 'One',
#   'Title': 'Algorithms to Live By: The Computer Science of Human Decisions',
#   '_id': ObjectId('6495541fa0480a0e669ef663')}
# { 'Price': 42.95,
#   'Star_rating': 'One',
#   'Title': 'A World of Flavor: Your Gluten Free Passport',
#   '_id': ObjectId('6495541fa0480a0e669ef664')}
# { 'Price': 56.76,
#   'Star_rating': 'Five',
#   'Title': 'A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations',
#   '_id': ObjectId('6495541fa0480a0e669ef665')}
# { 'Price': 16.64,
#   'Star_rating': 'One',
#   'Title': 'A Murder in Time',
#   '_id': ObjectId('6495541fa0480a0e669ef666')}
# { 'Price': 55.53,
#   'Star_rating': 'Five',
#   'Title': 'A Flight of Arrows (The Pathfinders #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef667')}
# { 'Price': 28.13,
#   'Star_rating': 'Four',
#   'Title': 'A Fierce and Subtle Poison',
#   '_id': ObjectId('6495541fa0480a0e669ef668')}
# { 'Price': 52.37,
#   'Star_rating': 'One',
#   'Title': 'A Court of Thorns and Roses (A Court of Thorns and Roses #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef669')}
# { 'Price': 54.0,
#   'Star_rating': 'Five',
#   'Title': '(Un)Qualified: How God Uses Broken People to Do Big Things',
#   '_id': ObjectId('6495541fa0480a0e669ef66a')}
# { 'Price': 21.87,
#   'Star_rating': 'Four',
#   'Title': 'You Are What You Love: The Spiritual Power of Habit',
#   '_id': ObjectId('6495541fa0480a0e669ef66b')}
# { 'Price': 43.3,
#   'Star_rating': 'Four',
#   'Title': "William Shakespeare's Star Wars: Verily, A New Hope (William "
#            "Shakespeare's Star Wars #4)",
#   '_id': ObjectId('6495541fa0480a0e669ef66c')}
# { 'Price': 21.04,
#   'Star_rating': 'Two',
#   'Title': 'Tuesday Nights in 1980',
#   '_id': ObjectId('6495541fa0480a0e669ef66d')}
# { 'Price': 41.6,
#   'Star_rating': 'Three',
#   'Title': 'Tracing Numbers on a Train',
#   '_id': ObjectId('6495541fa0480a0e669ef66e')}
# { 'Price': 35.07,
#   'Star_rating': 'Three',
#   'Title': 'Throne of Glass (Throne of Glass #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef66f')}
# { 'Price': 59.64,
#   'Star_rating': 'One',
#   'Title': 'Thomas Jefferson and the Tripoli Pirates: The Forgotten War That '
#            'Changed American History',
#   '_id': ObjectId('6495541fa0480a0e669ef670')}
# { 'Price': 52.72,
#   'Star_rating': 'One',
#   'Title': 'Thirteen Reasons Why',
#   '_id': ObjectId('6495541fa0480a0e669ef671')}
# { 'Price': 58.08,
#   'Star_rating': 'Four',
#   'Title': 'The White Cat and the Monk: A Retelling of the Poem “Pangur Bán”',
#   '_id': ObjectId('6495541fa0480a0e669ef672')}
# { 'Price': 24.12,
#   'Star_rating': 'One',
#   'Title': 'The Wedding Dress',
#   '_id': ObjectId('6495541fa0480a0e669ef673')}
# { 'Price': 42.15,
#   'Star_rating': 'Four',
#   'Title': 'The Vacationers',
#   '_id': ObjectId('6495541fa0480a0e669ef674')}
# { 'Price': 12.61,
#   'Star_rating': 'Five',
#   'Title': 'The Third Wave: An Entrepreneur’s Vision of the Future',
#   '_id': ObjectId('6495541fa0480a0e669ef675')}
# { 'Price': 17.44,
#   'Star_rating': 'Four',
#   'Title': 'The Stranger',
#   '_id': ObjectId('6495541fa0480a0e669ef676')}
# { 'Price': 33.14,
#   'Star_rating': 'One',
#   'Title': 'The Shadow Hero (The Shadow Hero)',
#   '_id': ObjectId('6495541fa0480a0e669ef677')}
# { 'Price': 27.37,
#   'Star_rating': 'Four',
#   'Title': 'The Secret (The Secret #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef678')}
# { 'Price': 51.36,
#   'Star_rating': 'Five',
#   'Title': 'The Regional Office Is Under Attack!',
#   '_id': ObjectId('6495541fa0480a0e669ef679')}
# { 'Price': 36.0,
#   'Star_rating': 'Two',
#   'Title': 'The Psychopath Test: A Journey Through the Madness Industry',
#   '_id': ObjectId('6495541fa0480a0e669ef67a')}
# { 'Price': 10.65,
#   'Star_rating': 'One',
#   'Title': 'The Project',
#   '_id': ObjectId('6495541fa0480a0e669ef67b')}
# { 'Price': 43.54,
#   'Star_rating': 'Two',
#   'Title': 'The Power of Now: A Guide to Spiritual Enlightenment',
#   '_id': ObjectId('6495541fa0480a0e669ef67c')}
# { 'Price': 38.21,
#   'Star_rating': 'Two',
#   'Title': "The Omnivore's Dilemma: A Natural History of Four Meals",
#   '_id': ObjectId('6495541fa0480a0e669ef67d')}
# { 'Price': 37.34,
#   'Star_rating': 'Five',
#   'Title': 'The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us',
#   '_id': ObjectId('6495541fa0480a0e669ef67e')}
# { 'Price': 44.1,
#   'Star_rating': 'Four',
#   'Title': 'The Murder of Roger Ackroyd (Hercule Poirot #4)',
#   '_id': ObjectId('6495541fa0480a0e669ef67f')}
# { 'Price': 43.29,
#   'Star_rating': 'Three',
#   'Title': 'The Mistake (Off-Campus #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef680')}
# { 'Price': 55.85,
#   'Star_rating': 'One',
#   'Title': "The Matchmaker's Playbook (Wingmen Inc. #1)",
#   '_id': ObjectId('6495541fa0480a0e669ef681')}
# { 'Price': 37.6,
#   'Star_rating': 'Two',
#   'Title': 'The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of '
#            'Impromptu Cooking',
#   '_id': ObjectId('6495541fa0480a0e669ef682')}
# { 'Price': 10.97,
#   'Star_rating': 'One',
#   'Title': 'The Long Shadow of Small Ghosts: Murder and Memory in an American '
#            'City',
#   '_id': ObjectId('6495541fa0480a0e669ef683')}
# { 'Price': 41.82,
#   'Star_rating': 'Four',
#   'Title': 'The Kite Runner',
#   '_id': ObjectId('6495541fa0480a0e669ef684')}
# { 'Price': 36.95,
#   'Star_rating': 'One',
#   'Title': 'The House by the Lake',
#   '_id': ObjectId('6495541fa0480a0e669ef685')}
# { 'Price': 44.28,
#   'Star_rating': 'One',
#   'Title': 'The Glittering Court (The Glittering Court #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef686')}
# { 'Price': 55.02,
#   'Star_rating': 'Two',
#   'Title': 'The Girl on the Train',
#   '_id': ObjectId('6495541fa0480a0e669ef687')}
# { 'Price': 17.24,
#   'Star_rating': 'One',
#   'Title': 'The Genius of Birds',
#   '_id': ObjectId('6495541fa0480a0e669ef688')}
# { 'Price': 23.15,
#   'Star_rating': 'Two',
#   'Title': 'The Emerald Mystery',
#   '_id': ObjectId('6495541fa0480a0e669ef689')}
# { 'Price': 41.25,
#   'Star_rating': 'One',
#   'Title': 'The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding '
#            'you to Always Eat Dessert First',
#   '_id': ObjectId('6495541fa0480a0e669ef68a')}
# { 'Price': 32.0,
#   'Star_rating': 'Three',
#   'Title': "The Bridge to Consciousness: I'm Writing the Bridge Between "
#            'Science and Our Old and New Beliefs.',
#   '_id': ObjectId('6495541fa0480a0e669ef68b')}
# { 'Price': 38.49,
#   'Star_rating': 'Five',
#   'Title': "The Artist's Way: A Spiritual Path to Higher Creativity",
#   '_id': ObjectId('6495541fa0480a0e669ef68c')}
# { 'Price': 33.34,
#   'Star_rating': 'Five',
#   'Title': 'The Art of War',
#   '_id': ObjectId('6495541fa0480a0e669ef68d')}
# { 'Price': 10.93,
#   'Star_rating': 'Two',
#   'Title': 'The Argonauts',
#   '_id': ObjectId('6495541fa0480a0e669ef68e')}
# { 'Price': 27.55,
#   'Star_rating': 'Three',
#   'Title': 'The 10% Entrepreneur: Live Your Startup Dream Without Quitting '
#            'Your Day Job',
#   '_id': ObjectId('6495541fa0480a0e669ef68f')}
# { 'Price': 55.99,
#   'Star_rating': 'Two',
#   'Title': 'Suddenly in Love (Lake Haven #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef690')}
# { 'Price': 16.24,
#   'Star_rating': 'Four',
#   'Title': 'Something More Than This',
#   '_id': ObjectId('6495541fa0480a0e669ef691')}
# { 'Price': 26.12,
#   'Star_rating': 'Two',
#   'Title': 'Soft Apocalypse',
#   '_id': ObjectId('6495541fa0480a0e669ef692')}
# { 'Price': 12.23,
#   'Star_rating': 'Two',
#   'Title': "So You've Been Publicly Shamed",
#   '_id': ObjectId('6495541fa0480a0e669ef693')}
# { 'Price': 23.99,
#   'Star_rating': 'Two',
#   'Title': 'Shoe Dog: A Memoir by the Creator of NIKE',
#   '_id': ObjectId('6495541fa0480a0e669ef694')}
# { 'Price': 29.06,
#   'Star_rating': 'Three',
#   'Title': 'Shobu Samurai, Project Aryoku (#3)',
#   '_id': ObjectId('6495541fa0480a0e669ef695')}
# { 'Price': 20.27,
#   'Star_rating': 'One',
#   'Title': 'Secrets and Lace (Fatal Hearts #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef696')}
# { 'Price': 43.55,
#   'Star_rating': 'Five',
#   'Title': 'Scarlett Epstein Hates It Here',
#   '_id': ObjectId('6495541fa0480a0e669ef697')}
# { 'Price': 36.94,
#   'Star_rating': 'One',
#   'Title': 'Romero and Juliet: A Tragic Tale of Love and Zombies',
#   '_id': ObjectId('6495541fa0480a0e669ef698')}
# { 'Price': 20.47,
#   'Star_rating': 'Five',
#   'Title': 'Redeeming Love',
#   '_id': ObjectId('6495541fa0480a0e669ef699')}
# { 'Price': 41.06,
#   'Star_rating': 'One',
#   'Title': 'Poses for Artists Volume 1 - Dynamic and Sitting Poses: An '
#            'Essential Reference for Figure Drawing and the Human Form',
#   '_id': ObjectId('6495541fa0480a0e669ef69a')}
# { 'Price': 14.19,
#   'Star_rating': 'Four',
#   'Title': 'Poems That Make Grown Women Cry',
#   '_id': ObjectId('6495541fa0480a0e669ef69b')}
# { 'Price': 38.28,
#   'Star_rating': 'One',
#   'Title': 'Nightingale, Sing',
#   '_id': ObjectId('6495541fa0480a0e669ef69c')}
# { 'Price': 41.05,
#   'Star_rating': 'One',
#   'Title': 'Night Sky with Exit Wounds',
#   '_id': ObjectId('6495541fa0480a0e669ef69d')}
# { 'Price': 30.25,
#   'Star_rating': 'Five',
#   'Title': 'Mrs. Houdini',
#   '_id': ObjectId('6495541fa0480a0e669ef69e')}
# { 'Price': 28.26,
#   'Star_rating': 'Five',
#   'Title': 'Modern Romance',
#   '_id': ObjectId('6495541fa0480a0e669ef69f')}
# { 'Price': 10.76,
#   'Star_rating': 'One',
#   'Title': 'Miss Peregrine’s Home for Peculiar Children (Miss Peregrine’s '
#            'Peculiar Children #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef6a0')}
# { 'Price': 16.85,
#   'Star_rating': 'Two',
#   'Title': 'Louisa: The Extraordinary Life of Mrs. Adams',
#   '_id': ObjectId('6495541fa0480a0e669ef6a1')}
# { 'Price': 13.47,
#   'Star_rating': 'Three',
#   'Title': 'Little Red',
#   '_id': ObjectId('6495541fa0480a0e669ef6a2')}
# { 'Price': 48.56,
#   'Star_rating': 'Five',
#   'Title': 'Library of Souls (Miss Peregrine’s Peculiar Children #3)',
#   '_id': ObjectId('6495541fa0480a0e669ef6a3')}
# { 'Price': 19.15,
#   'Star_rating': 'Two',
#   'Title': 'Large Print Heart of the Pride',
#   '_id': ObjectId('6495541fa0480a0e669ef6a4')}
# { 'Price': 57.36,
#   'Star_rating': 'Four',
#   'Title': 'I Had a Nice Time And Other Lies...: How to find love & sh*t like '
#            'that',
#   '_id': ObjectId('6495541fa0480a0e669ef6a5')}
# { 'Price': 42.98,
#   'Star_rating': 'One',
#   'Title': 'Hollow City (Miss Peregrine’s Peculiar Children #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef6a6')}
# { 'Price': 22.16,
#   'Star_rating': 'Two',
#   'Title': 'Grumbles',
#   '_id': ObjectId('6495541fa0480a0e669ef6a7')}
# { 'Price': 49.43,
#   'Star_rating': 'Four',
#   'Title': 'Full Moon over Noah’s Ark: An Odyssey to Mount Ararat and Beyond',
#   '_id': ObjectId('6495541fa0480a0e669ef6a8')}
# { 'Price': 29.99,
#   'Star_rating': 'Five',
#   'Title': 'Frostbite (Vampire Academy #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef6a9')}
# { 'Price': 21.36,
#   'Star_rating': 'One',
#   'Title': 'Follow You Home',
#   '_id': ObjectId('6495541fa0480a0e669ef6aa')}
# { 'Price': 29.0,
#   'Star_rating': 'One',
#   'Title': 'First Steps for New Christians (Print Edition)',
#   '_id': ObjectId('6495541fa0480a0e669ef6ab')}
# { 'Price': 53.53,
#   'Star_rating': 'Five',
#   'Title': 'Finders Keepers (Bill Hodges Trilogy #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef6ac')}
# { 'Price': 41.62,
#   'Star_rating': 'Four',
#   'Title': 'Fables, Vol. 1: Legends in Exile (Fables #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef6ad')}
# { 'Price': 54.59,
#   'Star_rating': 'Four',
#   'Title': 'Eureka Trivia 6.0',
#   '_id': ObjectId('6495541fa0480a0e669ef6ae')}
# { 'Price': 34.95,
#   'Star_rating': 'Four',
#   'Title': 'Drive: The Surprising Truth About What Motivates Us',
#   '_id': ObjectId('6495541fa0480a0e669ef6af')}
# { 'Price': 37.72,
#   'Star_rating': 'Five',
#   'Title': 'Done Rubbed Out (Reightman & Bailey #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef6b0')}
# { 'Price': 35.61,
#   'Star_rating': 'Three',
#   'Title': 'Doing It Over (Most Likely To #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef6b1')}
# { 'Price': 42.16,
#   'Star_rating': 'Three',
#   'Title': 'Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free '
#            'Snacks, Packed Lunches, and Simple Meals',
#   '_id': ObjectId('6495541fa0480a0e669ef6b2')}
# { 'Price': 19.19,
#   'Star_rating': 'Five',
#   'Title': 'Dark Notes',
#   '_id': ObjectId('6495541fa0480a0e669ef6b3')}
# { 'Price': 19.43,
#   'Star_rating': 'Three',
#   'Title': 'Daring Greatly: How the Courage to Be Vulnerable Transforms the '
#            'Way We Live, Love, Parent, and Lead',
#   '_id': ObjectId('6495541fa0480a0e669ef6b4')}
# { 'Price': 49.46,
#   'Star_rating': 'Four',
#   'Title': 'Close to You',
#   '_id': ObjectId('6495541fa0480a0e669ef6b5')}
# { 'Price': 37.8,
#   'Star_rating': 'Two',
#   'Title': 'Chasing Heaven: What Dying Taught Me About Living',
#   '_id': ObjectId('6495541fa0480a0e669ef6b6')}
# { 'Price': 30.8,
#   'Star_rating': 'Three',
#   'Title': 'Big Magic: Creative Living Beyond Fear',
#   '_id': ObjectId('6495541fa0480a0e669ef6b7')}
# { 'Price': 27.43,
#   'Star_rating': 'Two',
#   'Title': 'Becoming Wise: An Inquiry into the Mystery and Art of Living',
#   '_id': ObjectId('6495541fa0480a0e669ef6b8')}
# { 'Price': 11.11,
#   'Star_rating': 'Two',
#   'Title': 'Beauty Restored (Riley Family Legacy Novellas #3)',
#   '_id': ObjectId('6495541fa0480a0e669ef6b9')}
# { 'Price': 36.5,
#   'Star_rating': 'Two',
#   'Title': 'Batman: The Long Halloween (Batman)',
#   '_id': ObjectId('6495541fa0480a0e669ef6ba')}
# { 'Price': 15.38,
#   'Star_rating': 'Five',
#   'Title': 'Batman: The Dark Knight Returns (Batman)',
#   '_id': ObjectId('6495541fa0480a0e669ef6bb')}
# { 'Price': 15.48,
#   'Star_rating': 'Two',
#   'Title': "Ayumi's Violin",
#   '_id': ObjectId('6495541fa0480a0e669ef6bc')}
# { 'Price': 46.82,
#   'Star_rating': 'Four',
#   'Title': 'Anonymous',
#   '_id': ObjectId('6495541fa0480a0e669ef6bd')}
# { 'Price': 18.46,
#   'Star_rating': 'Three',
#   'Title': 'Amy Meets the Saints and Sages',
#   '_id': ObjectId('6495541fa0480a0e669ef6be')}
# { 'Price': 36.58,
#   'Star_rating': 'One',
#   'Title': 'Amid the Chaos',
#   '_id': ObjectId('6495541fa0480a0e669ef6bf')}
# { 'Price': 50.54,
#   'Star_rating': 'Five',
#   'Title': 'Amatus',
#   '_id': ObjectId('6495541fa0480a0e669ef6c0')}
# { 'Price': 12.51,
#   'Star_rating': 'Five',
#   'Title': 'Agnostic: A Spirited Manifesto',
#   '_id': ObjectId('6495541fa0480a0e669ef6c1')}
# { 'Price': 24.7,
#   'Star_rating': 'Three',
#   'Title': 'Zealot: The Life and Times of Jesus of Nazareth',
#   '_id': ObjectId('6495541fa0480a0e669ef6c2')}
# { 'Price': 43.61,
#   'Star_rating': 'Five',
#   'Title': 'You (You #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef6c3')}
# { 'Price': 37.34,
#   'Star_rating': 'Four',
#   'Title': 'Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef6c4')}
# { 'Price': 14.36,
#   'Star_rating': 'Two',
#   'Title': 'Wild Swans',
#   '_id': ObjectId('6495541fa0480a0e669ef6c5')}
# { 'Price': 52.65,
#   'Star_rating': 'Four',
#   'Title': 'Why the Right Went Wrong: Conservatism--From Goldwater to the Tea '
#            'Party and Beyond',
#   '_id': ObjectId('6495541fa0480a0e669ef6c6')}
# { 'Price': 38.2,
#   'Star_rating': 'Four',
#   'Title': 'Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to '
#            'Awaken and Strengthen Your Creativity',
#   '_id': ObjectId('6495541fa0480a0e669ef6c7')}
# { 'Price': 19.6,
#   'Star_rating': 'Two',
#   'Title': "What's It Like in Space?: Stories from Astronauts Who've Been "
#            'There',
#   '_id': ObjectId('6495541fa0480a0e669ef6c8')}
# { 'Price': 53.9,
#   'Star_rating': 'One',
#   'Title': 'We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef6c9')}
# { 'Price': 12.96,
#   'Star_rating': 'Five',
#   'Title': "Walt Disney's Alice in Wonderland",
#   '_id': ObjectId('6495541fa0480a0e669ef6ca')}
# { 'Price': 37.1,
#   'Star_rating': 'Four',
#   'Title': 'V for Vendetta (V for Vendetta Complete)',
#   '_id': ObjectId('6495541fa0480a0e669ef6cb')}
# { 'Price': 46.31,
#   'Star_rating': 'Two',
#   'Title': 'Until Friday Night (The Field Party #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef6cc')}
# { 'Price': 45.95,
#   'Star_rating': 'Two',
#   'Title': 'Unbroken: A World War II Story of Survival, Resilience, and '
#            'Redemption',
#   '_id': ObjectId('6495541fa0480a0e669ef6cd')}
# { 'Price': 22.08,
#   'Star_rating': 'Two',
#   'Title': 'Twenty Yawns',
#   '_id': ObjectId('6495541fa0480a0e669ef6ce')}
# { 'Price': 25.38,
#   'Star_rating': 'Two',
#   'Title': 'Through the Woods',
#   '_id': ObjectId('6495541fa0480a0e669ef6cf')}
# { 'Price': 27.12,
#   'Star_rating': 'Two',
#   'Title': 'This Is Where It Ends',
#   '_id': ObjectId('6495541fa0480a0e669ef6d0')}
# { 'Price': 43.04,
#   'Star_rating': 'Two',
#   'Title': 'The Year of Magical Thinking',
#   '_id': ObjectId('6495541fa0480a0e669ef6d1')}
# { 'Price': 56.8,
#   'Star_rating': 'Four',
#   'Title': 'The Wright Brothers',
#   '_id': ObjectId('6495541fa0480a0e669ef6d2')}
# { 'Price': 25.91,
#   'Star_rating': 'Five',
#   'Title': "The White Queen (The Cousins' War #1)",
#   '_id': ObjectId('6495541fa0480a0e669ef6d3')}
# { 'Price': 32.61,
#   'Star_rating': 'Three',
#   'Title': "The Wedding Pact (The O'Malleys #2)",
#   '_id': ObjectId('6495541fa0480a0e669ef6d4')}
# { 'Price': 27.88,
#   'Star_rating': 'Five',
#   'Title': 'The Time Keeper',
#   '_id': ObjectId('6495541fa0480a0e669ef6d5')}
# { 'Price': 52.67,
#   'Star_rating': 'Four',
#   'Title': 'The Testament of Mary',
#   '_id': ObjectId('6495541fa0480a0e669ef6d6')}
# { 'Price': 46.02,
#   'Star_rating': 'Five',
#   'Title': 'The Star-Touched Queen',
#   '_id': ObjectId('6495541fa0480a0e669ef6d7')}
# { 'Price': 44.48,
#   'Star_rating': 'Five',
#   'Title': 'The Songs of the Gods',
#   '_id': ObjectId('6495541fa0480a0e669ef6d8')}
# { 'Price': 37.4,
#   'Star_rating': 'Five',
#   'Title': 'The Song of Achilles',
#   '_id': ObjectId('6495541fa0480a0e669ef6d9')}
# { 'Price': 54.04,
#   'Star_rating': 'One',
#   'Title': 'The Rosie Project (Don Tillman #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef6da')}
# { 'Price': 16.88,
#   'Star_rating': 'Three',
#   'Title': 'The Power of Habit: Why We Do What We Do in Life and Business',
#   '_id': ObjectId('6495541fa0480a0e669ef6db')}
# { 'Price': 28.08,
#   'Star_rating': 'Four',
#   'Title': 'The Marriage of Opposites',
#   '_id': ObjectId('6495541fa0480a0e669ef6dc')}
# { 'Price': 10.4,
#   'Star_rating': 'One',
#   'Title': 'The Lucifer Effect: Understanding How Good People Turn Evil',
#   '_id': ObjectId('6495541fa0480a0e669ef6dd')}
# { 'Price': 44.07,
#   'Star_rating': 'One',
#   'Title': 'The Long Haul (Diary of a Wimpy Kid #9)',
#   '_id': ObjectId('6495541fa0480a0e669ef6de')}
# { 'Price': 23.4,
#   'Star_rating': 'One',
#   'Title': 'The Loney',
#   '_id': ObjectId('6495541fa0480a0e669ef6df')}
# { 'Price': 17.43,
#   'Star_rating': 'Three',
#   'Title': 'The Literature Book (Big Ideas Simply Explained)',
#   '_id': ObjectId('6495541fa0480a0e669ef6e0')}
# { 'Price': 54.21,
#   'Star_rating': 'Two',
#   'Title': 'The Last Mile (Amos Decker #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef6e1')}
# { 'Price': 40.67,
#   'Star_rating': 'Two',
#   'Title': 'The Immortal Life of Henrietta Lacks',
#   '_id': ObjectId('6495541fa0480a0e669ef6e2')}
# { 'Price': 52.26,
#   'Star_rating': 'Two',
#   'Title': 'The Hidden Oracle (The Trials of Apollo #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef6e3')}
# { 'Price': 28.77,
#   'Star_rating': 'Three',
#   'Title': 'The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Recipes '
#            'Kids Can Make to Stay Healthy and Save the Earth',
#   '_id': ObjectId('6495541fa0480a0e669ef6e4')}
# { 'Price': 13.82,
#   'Star_rating': 'Two',
#   'Title': 'The Guilty (Will Robie #4)',
#   '_id': ObjectId('6495541fa0480a0e669ef6e5')}
# { 'Price': 25.85,
#   'Star_rating': 'Three',
#   'Title': 'The First Hostage (J.B. Collins #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef6e6')}
# { 'Price': 48.78,
#   'Star_rating': 'One',
#   'Title': 'The Dovekeepers',
#   '_id': ObjectId('6495541fa0480a0e669ef6e7')}
# { 'Price': 35.35,
#   'Star_rating': 'Five',
#   'Title': 'The Darkest Lie',
#   '_id': ObjectId('6495541fa0480a0e669ef6e8')}
# { 'Price': 44.73,
#   'Star_rating': 'Four',
#   'Title': 'The Bane Chronicles (The Bane Chronicles #1-11)',
#   '_id': ObjectId('6495541fa0480a0e669ef6e9')}
# { 'Price': 15.77,
#   'Star_rating': 'One',
#   'Title': 'The Bad-Ass Librarians of Timbuktu: And Their Race to Save the '
#            'World’s Most Precious Manuscripts',
#   '_id': ObjectId('6495541fa0480a0e669ef6ea')}
# { 'Price': 39.24,
#   'Star_rating': 'One',
#   'Title': 'The 14th Colony (Cotton Malone #11)',
#   '_id': ObjectId('6495541fa0480a0e669ef6eb')}
# { 'Price': 13.92,
#   'Star_rating': 'One',
#   'Title': 'That Darkness (Gardiner and Renner #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef6ec')}
# { 'Price': 10.69,
#   'Star_rating': 'One',
#   'Title': 'Tastes Like Fear (DI Marnie Rome #3)',
#   '_id': ObjectId('6495541fa0480a0e669ef6ed')}
# { 'Price': 45.21,
#   'Star_rating': 'Three',
#   'Title': 'Take Me with You',
#   '_id': ObjectId('6495541fa0480a0e669ef6ee')}
# { 'Price': 45.58,
#   'Star_rating': 'One',
#   'Title': 'Swell: A Year of Waves',
#   '_id': ObjectId('6495541fa0480a0e669ef6ef')}
# { 'Price': 11.89,
#   'Star_rating': 'Five',
#   'Title': 'Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef6f0')}
# { 'Price': 26.41,
#   'Star_rating': 'Three',
#   'Title': 'Still Life with Bread Crumbs',
#   '_id': ObjectId('6495541fa0480a0e669ef6f1')}
# { 'Price': 39.5,
#   'Star_rating': 'Five',
#   'Title': 'Steve Jobs',
#   '_id': ObjectId('6495541fa0480a0e669ef6f2')}
# { 'Price': 44.74,
#   'Star_rating': 'Four',
#   'Title': 'Sorting the Beef from the Bull: The Science of Food Fraud '
#            'Forensics',
#   '_id': ObjectId('6495541fa0480a0e669ef6f3')}
# { 'Price': 52.79,
#   'Star_rating': 'Five',
#   'Title': 'Someone Like You (The Harrisons #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef6f4')}
# { 'Price': 35.43,
#   'Star_rating': 'Four',
#   'Title': 'So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)',
#   '_id': ObjectId('6495541fa0480a0e669ef6f5')}
# { 'Price': 55.84,
#   'Star_rating': 'Four',
#   'Title': 'Shtum',
#   '_id': ObjectId('6495541fa0480a0e669ef6f6')}
# { 'Price': 48.87,
#   'Star_rating': 'Three',
#   'Title': 'See America: A Celebration of Our National Parks & Treasured Sites',
#   '_id': ObjectId('6495541fa0480a0e669ef6f7')}
# { 'Price': 46.78,
#   'Star_rating': 'Four',
#   'Title': 'salt.',
#   '_id': ObjectId('6495541fa0480a0e669ef6f8')}
# { 'Price': 47.82,
#   'Star_rating': 'Three',
#   'Title': 'Robin War',
#   '_id': ObjectId('6495541fa0480a0e669ef6f9')}
# { 'Price': 25.48,
#   'Star_rating': 'Two',
#   'Title': 'Red Hood/Arsenal, Vol. 1: Open for Business (Red Hood/Arsenal #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef6fa')}
# { 'Price': 23.57,
#   'Star_rating': 'Three',
#   'Title': 'Rain Fish',
#   '_id': ObjectId('6495541fa0480a0e669ef6fb')}
# { 'Price': 50.89,
#   'Star_rating': 'Five',
#   'Title': 'Quarter Life Poetry: Poems for the Young, Broke and Hangry',
#   '_id': ObjectId('6495541fa0480a0e669ef6fc')}
# { 'Price': 10.56,
#   'Star_rating': 'Three',
#   'Title': 'Pet Sematary',
#   '_id': ObjectId('6495541fa0480a0e669ef6fd')}
# { 'Price': 52.15,
#   'Star_rating': 'Three',
#   'Title': 'Overload: How to Unplug, Unwind, and Unleash Yourself from the '
#            'Pressure of Stress',
#   '_id': ObjectId('6495541fa0480a0e669ef6fe')}
# { 'Price': 18.28,
#   'Star_rating': 'Two',
#   'Title': 'Once Was a Time',
#   '_id': ObjectId('6495541fa0480a0e669ef6ff')}
# { 'Price': 11.83,
#   'Star_rating': 'Five',
#   'Title': 'Old School (Diary of a Wimpy Kid #10)',
#   '_id': ObjectId('6495541fa0480a0e669ef700')}
# { 'Price': 21.95,
#   'Star_rating': 'Two',
#   'Title': 'No Dream Is Too High: Life Lessons From a Man Who Walked on the '
#            'Moon',
#   '_id': ObjectId('6495541fa0480a0e669ef701')}
# { 'Price': 38.39,
#   'Star_rating': 'Two',
#   'Title': 'Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42 '
#            '(Naruto: Omnibus #14)',
#   '_id': ObjectId('6495541fa0480a0e669ef702')}
# { 'Price': 41.56,
#   'Star_rating': 'One',
#   'Title': 'My Name Is Lucy Barton',
#   '_id': ObjectId('6495541fa0480a0e669ef703')}
# { 'Price': 24.48,
#   'Star_rating': 'Three',
#   'Title': 'My Mrs. Brown',
#   '_id': ObjectId('6495541fa0480a0e669ef704')}
# { 'Price': 40.36,
#   'Star_rating': 'One',
#   'Title': 'My Kind of Crazy',
#   '_id': ObjectId('6495541fa0480a0e669ef705')}
# { 'Price': 28.9,
#   'Star_rating': 'One',
#   'Title': 'Mr. Mercedes (Bill Hodges Trilogy #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef706')}
# { 'Price': 37.61,
#   'Star_rating': 'Two',
#   'Title': 'More Than Music (Chasing the Dream #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef707')}
# { 'Price': 38.85,
#   'Star_rating': 'Five',
#   'Title': 'Made to Stick: Why Some Ideas Survive and Others Die',
#   '_id': ObjectId('6495541fa0480a0e669ef708')}
# { 'Price': 53.95,
#   'Star_rating': 'Three',
#   'Title': 'Luis Paints the World',
#   '_id': ObjectId('6495541fa0480a0e669ef709')}
# { 'Price': 49.83,
#   'Star_rating': 'Three',
#   'Title': 'Luckiest Girl Alive',
#   '_id': ObjectId('6495541fa0480a0e669ef70a')}
# { 'Price': 51.51,
#   'Star_rating': 'Two',
#   'Title': 'Lowriders to the Center of the Earth (Lowriders in Space #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef70b')}
# { 'Price': 18.03,
#   'Star_rating': 'One',
#   'Title': 'Love Is a Mix Tape (Music #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef70c')}
# { 'Price': 29.14,
#   'Star_rating': 'Five',
#   'Title': 'Looking for Lovely: Collecting the Moments that Matter',
#   '_id': ObjectId('6495541fa0480a0e669ef70d')}
# { 'Price': 46.91,
#   'Star_rating': 'Four',
#   'Title': 'Living Leadership by Insight: A Good Leader Achieves, a Great '
#            'Leader Builds Monuments',
#   '_id': ObjectId('6495541fa0480a0e669ef70e')}
# { 'Price': 26.79,
#   'Star_rating': 'Five',
#   'Title': 'Let It Out: A Journey Through Journaling',
#   '_id': ObjectId('6495541fa0480a0e669ef70f')}
# { 'Price': 16.28,
#   'Star_rating': 'Five',
#   'Title': 'Lady Midnight (The Dark Artifices #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef710')}
# { 'Price': 19.55,
#   'Star_rating': 'One',
#   'Title': "It's All Easy: Healthy, Delicious Weeknight Meals in under 30 "
#            'Minutes',
#   '_id': ObjectId('6495541fa0480a0e669ef711')}
# { 'Price': 29.65,
#   'Star_rating': 'One',
#   'Title': 'Island of Dragons (Unwanteds #7)',
#   '_id': ObjectId('6495541fa0480a0e669ef712')}
# { 'Price': 25.98,
#   'Star_rating': 'Four',
#   'Title': "I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches "
#            'from a Life Under Construction',
#   '_id': ObjectId('6495541fa0480a0e669ef713')}
# { 'Price': 10.6,
#   'Star_rating': 'Four',
#   'Title': 'I Am Pilgrim (Pilgrim #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef714')}
# { 'Price': 14.75,
#   'Star_rating': 'Five',
#   'Title': 'Hyperbole and a Half: Unfortunate Situations, Flawed Coping '
#            'Mechanisms, Mayhem, and Other Things That Happened',
#   '_id': ObjectId('6495541fa0480a0e669ef715')}
# { 'Price': 47.02,
#   'Star_rating': 'Three',
#   'Title': 'Hush, Hush (Hush, Hush #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef716')}
# { 'Price': 28.82,
#   'Star_rating': 'One',
#   'Title': 'Hold Your Breath (Search and Rescue #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef717')}
# { 'Price': 58.79,
#   'Star_rating': 'Three',
#   'Title': 'Hamilton: The Revolution',
#   '_id': ObjectId('6495541fa0480a0e669ef718')}
# { 'Price': 10.23,
#   'Star_rating': 'Five',
#   'Title': 'Greek Mythic History',
#   '_id': ObjectId('6495541fa0480a0e669ef719')}
# { 'Price': 30.03,
#   'Star_rating': 'Five',
#   'Title': 'God: The Most Unpleasant Character in All Fiction',
#   '_id': ObjectId('6495541fa0480a0e669ef71a')}
# { 'Price': 45.84,
#   'Star_rating': 'Three',
#   'Title': 'Glory over Everything: Beyond The Kitchen House',
#   '_id': ObjectId('6495541fa0480a0e669ef71b')}
# { 'Price': 49.05,
#   'Star_rating': 'Three',
#   'Title': 'Feathers: Displays of Brilliant Plumage',
#   '_id': ObjectId('6495541fa0480a0e669ef71c')}
# { 'Price': 15.06,
#   'Star_rating': 'Four',
#   'Title': 'Far & Away: Places on the Brink of Change: Seven Continents, '
#            'Twenty-Five Years',
#   '_id': ObjectId('6495541fa0480a0e669ef71d')}
# { 'Price': 46.47,
#   'Star_rating': 'Three',
#   'Title': 'Every Last Word',
#   '_id': ObjectId('6495541fa0480a0e669ef71e')}
# { 'Price': 27.09,
#   'Star_rating': 'Three',
#   'Title': 'Eligible (The Austen Project #4)',
#   '_id': ObjectId('6495541fa0480a0e669ef71f')}
# { 'Price': 57.62,
#   'Star_rating': 'Five',
#   'Title': 'El Deafo',
#   '_id': ObjectId('6495541fa0480a0e669ef720')}
# { 'Price': 14.39,
#   'Star_rating': 'Four',
#   'Title': 'Eight Hundred Grapes',
#   '_id': ObjectId('6495541fa0480a0e669ef721')}
# { 'Price': 51.75,
#   'Star_rating': 'Five',
#   'Title': 'Eaternity: More than 150 Deliciously Easy Vegan Recipes for a '
#            'Long, Healthy, Satisfied, Joyful Life',
#   '_id': ObjectId('6495541fa0480a0e669ef722')}
# { 'Price': 54.07,
#   'Star_rating': 'Two',
#   'Title': 'Eat Fat, Get Thin',
#   '_id': ObjectId('6495541fa0480a0e669ef723')}
# { 'Price': 55.35,
#   'Star_rating': 'One',
#   'Title': "Don't Get Caught",
#   '_id': ObjectId('6495541fa0480a0e669ef724')}
# { 'Price': 40.12,
#   'Star_rating': 'Two',
#   'Title': 'Doctor Sleep (The Shining #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef725')}
# { 'Price': 37.51,
#   'Star_rating': 'Five',
#   'Title': 'Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy '
#            'Jackson & Kane Chronicles Crossover #1-3)',
#   '_id': ObjectId('6495541fa0480a0e669ef726')}
# { 'Price': 11.21,
#   'Star_rating': 'Five',
#   'Title': 'Dear Mr. Knightley',
#   '_id': ObjectId('6495541fa0480a0e669ef727')}
# { 'Price': 36.58,
#   'Star_rating': 'One',
#   'Title': 'Daily Fantasy Sports',
#   '_id': ObjectId('6495541fa0480a0e669ef728')}
# { 'Price': 47.72,
#   'Star_rating': 'Two',
#   'Title': 'Crazy Love: Overwhelmed by a Relentless God',
#   '_id': ObjectId('6495541fa0480a0e669ef729')}
# { 'Price': 25.01,
#   'Star_rating': 'Three',
#   'Title': 'Cometh the Hour (The Clifton Chronicles #6)',
#   '_id': ObjectId('6495541fa0480a0e669ef72a')}
# { 'Price': 22.13,
#   'Star_rating': 'Four',
# ...
#   '_id': ObjectId('6495541fa0480a0e669ef95e')}
# { 'Price': 31.22,
#   'Star_rating': 'Two',
#   'Title': 'A Storm of Swords (A Song of Ice and Fire #3)',
#   '_id': ObjectId('6495541fa0480a0e669ef95f')}
# { 'Price': 54.29,
#   'Star_rating': 'Five',
#   'Title': 'A Heartbreaking Work of Staggering Genius',
#   '_id': ObjectId('6495541fa0480a0e669ef960')}
# { 'Price': 31.04,
#   'Star_rating': 'One',
#   'Title': '8 Keys to Mental Health Through Exercise',
#   '_id': ObjectId('6495541fa0480a0e669ef961')}
# { 'Price': 50.96,
#   'Star_rating': 'One',
#   'Title': '#GIRLBOSS',
#   '_id': ObjectId('6495541fa0480a0e669ef962')}
# { 'Price': 11.89,
#   'Star_rating': 'Two',
#   'Title': 'The Suffragettes (Little Black Classics, #96)',
#   '_id': ObjectId('6495541fa0480a0e669ef963')}
# { 'Price': 31.38,
#   'Star_rating': 'Three',
#   'Title': 'The Sense of an Ending',
#   '_id': ObjectId('6495541fa0480a0e669ef964')}
# { 'Price': 54.81,
#   'Star_rating': 'One',
#   'Title': "The Sandman, Vol. 2: The Doll's House (The Sandman (volumes) #2)",
#   '_id': ObjectId('6495541fa0480a0e669ef965')}
# { 'Price': 16.78,
#   'Star_rating': 'Three',
#   'Title': 'The Course of Love',
#   '_id': ObjectId('6495541fa0480a0e669ef966')}
# { 'Price': 24.42,
#   'Star_rating': 'One',
#   'Title': 'Sugar Rush (Offensive Line #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef967')}
# { 'Price': 11.75,
#   'Star_rating': 'Three',
#   'Title': 'Saga, Volume 2 (Saga (Collected Editions) #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef968')}
# { 'Price': 20.02,
#   'Star_rating': 'One',
#   'Title': 'Run, Spot, Run: The Ethics of Keeping Pets',
#   '_id': ObjectId('6495541fa0480a0e669ef969')}
# { 'Price': 12.86,
#   'Star_rating': 'Four',
#   'Title': 'New Moon (Twilight #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef96a')}
# { 'Price': 31.58,
#   'Star_rating': 'Five',
#   'Title': 'Life',
#   '_id': ObjectId('6495541fa0480a0e669ef96b')}
# { 'Price': 34.0,
#   'Star_rating': 'Three',
#   'Title': "Kindle Paperwhite User's Guide",
#   '_id': ObjectId('6495541fa0480a0e669ef96c')}
# { 'Price': 57.42,
#   'Star_rating': 'Five',
#   'Title': 'H is for Hawk',
#   '_id': ObjectId('6495541fa0480a0e669ef96d')}
# { 'Price': 53.47,
#   'Star_rating': 'One',
#   'Title': 'Girl Online On Tour (Girl Online #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef96e')}
# { 'Price': 11.64,
#   'Star_rating': 'Five',
#   'Title': 'Fruits Basket, Vol. 2 (Fruits Basket #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef96f')}
# { 'Price': 52.88,
#   'Star_rating': 'Four',
#   'Title': 'Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An '
#            'Unofficial Minecraft Book)',
#   '_id': ObjectId('6495541fa0480a0e669ef970')}
# { 'Price': 18.51,
#   'Star_rating': 'Four',
#   'Title': 'Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef971')}
# { 'Price': 41.32,
#   'Star_rating': 'Five',
#   'Title': 'While You Were Mine',
#   '_id': ObjectId('6495541fa0480a0e669ef972')}
# { 'Price': 39.77,
#   'Star_rating': 'Three',
#   'Title': 'Where Lightning Strikes (Bleeding Stars #3)',
#   '_id': ObjectId('6495541fa0480a0e669ef973')}
# { 'Price': 51.96,
#   'Star_rating': 'Three',
#   'Title': "When I'm Gone",
#   '_id': ObjectId('6495541fa0480a0e669ef974')}
# { 'Price': 39.51,
#   'Star_rating': 'Five',
#   'Title': 'Ways of Seeing',
#   '_id': ObjectId('6495541fa0480a0e669ef975')}
# { 'Price': 15.4,
#   'Star_rating': 'One',
#   'Title': 'Vampire Knight, Vol. 1 (Vampire Knight #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef976')}
# { 'Price': 53.82,
#   'Star_rating': 'Two',
#   'Title': 'Vampire Girl (Vampire Girl #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef977')}
# { 'Price': 30.95,
#   'Star_rating': 'Four',
#   'Title': 'Twenty Love Poems and a Song of Despair',
#   '_id': ObjectId('6495541fa0480a0e669ef978')}
# { 'Price': 57.82,
#   'Star_rating': 'Five',
#   'Title': 'Travels with Charley: In Search of America',
#   '_id': ObjectId('6495541fa0480a0e669ef979')}
# { 'Price': 44.18,
#   'Star_rating': 'Two',
#   'Title': 'Three Wishes (River of Time: California #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef97a')}
# { 'Price': 48.71,
#   'Star_rating': 'One',
#   'Title': 'This One Moment (Pushing Limits #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef97b')}
# { 'Price': 19.69,
#   'Star_rating': 'Five',
#   'Title': 'The Zombie Room',
#   '_id': ObjectId('6495541fa0480a0e669ef97c')}
# { 'Price': 36.52,
#   'Star_rating': 'Two',
#   'Title': 'The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The '
#            'Divine)',
#   '_id': ObjectId('6495541fa0480a0e669ef97d')}
# { 'Price': 41.56,
#   'Star_rating': 'Five',
#   'Title': 'The Tumor',
#   '_id': ObjectId('6495541fa0480a0e669ef97e')}
# { 'Price': 43.19,
#   'Star_rating': 'Four',
#   'Title': 'The Story of Hong Gildong',
#   '_id': ObjectId('6495541fa0480a0e669ef97f')}
# { 'Price': 12.34,
#   'Star_rating': 'Five',
#   'Title': 'The Silent Wife',
#   '_id': ObjectId('6495541fa0480a0e669ef980')}
# { 'Price': 36.25,
#   'Star_rating': 'Three',
#   'Title': 'The Silent Twin (Detective Jennifer Knight #3)',
#   '_id': ObjectId('6495541fa0480a0e669ef981')}
# { 'Price': 29.45,
#   'Star_rating': 'One',
#   'Title': 'The Selfish Gene',
#   '_id': ObjectId('6495541fa0480a0e669ef982')}
# { 'Price': 34.56,
#   'Star_rating': 'Three',
#   'Title': 'The Secret Healer',
#   '_id': ObjectId('6495541fa0480a0e669ef983')}
# { 'Price': 54.12,
#   'Star_rating': 'Three',
#   'Title': 'The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) '
#            '#1)',
#   '_id': ObjectId('6495541fa0480a0e669ef984')}
# { 'Price': 33.78,
#   'Star_rating': 'Three',
#   'Title': 'The Republic',
#   '_id': ObjectId('6495541fa0480a0e669ef985')}
# { 'Price': 29.64,
#   'Star_rating': 'Three',
#   'Title': 'The Odyssey',
#   '_id': ObjectId('6495541fa0480a0e669ef986')}
# { 'Price': 57.7,
#   'Star_rating': 'Four',
#   'Title': "The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency "
#            '#1)',
#   '_id': ObjectId('6495541fa0480a0e669ef987')}
# { 'Price': 36.34,
#   'Star_rating': 'One',
#   'Title': 'The Nicomachean Ethics',
#   '_id': ObjectId('6495541fa0480a0e669ef988')}
# { 'Price': 50.59,
#   'Star_rating': 'Three',
#   'Title': 'The Name of the Wind (The Kingkiller Chronicle #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef989')}
# { 'Price': 29.38,
#   'Star_rating': 'One',
#   'Title': 'The Mirror & the Maze (The Wrath and the Dawn #1.5)',
#   '_id': ObjectId('6495541fa0480a0e669ef98a')}
# { 'Price': 45.42,
#   'Star_rating': 'Two',
#   'Title': 'The Little Prince',
#   '_id': ObjectId('6495541fa0480a0e669ef98b')}
# { 'Price': 54.43,
#   'Star_rating': 'One',
#   'Title': 'The Light of the Fireflies',
#   '_id': ObjectId('6495541fa0480a0e669ef98c')}
# { 'Price': 36.26,
#   'Star_rating': 'Two',
#   'Title': 'The Last Girl (The Dominion Trilogy #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef98d')}
# { 'Price': 16.16,
#   'Star_rating': 'One',
#   'Title': 'The Iliad',
#   '_id': ObjectId('6495541fa0480a0e669ef98e')}
# { 'Price': 36.29,
#   'Star_rating': 'Five',
#   'Title': 'The Hook Up (Game On #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef98f')}
# { 'Price': 27.89,
#   'Star_rating': 'Five',
#   'Title': 'The Haters',
#   '_id': ObjectId('6495541fa0480a0e669ef990')}
# { 'Price': 12.29,
#   'Star_rating': 'Five',
#   'Title': 'The Girl You Lost',
#   '_id': ObjectId('6495541fa0480a0e669ef991')}
# { 'Price': 15.85,
#   'Star_rating': 'Three',
#   'Title': 'The Girl In The Ice (DCI Erika Foster #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef992')}
# { 'Price': 14.4,
#   'Star_rating': 'One',
#   'Title': 'The End of the Jesus Era (An Investigation #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef993')}
# { 'Price': 19.18,
#   'Star_rating': 'Four',
#   'Title': 'The Edge of Reason (Bridget Jones #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef994')}
# { 'Price': 10.64,
#   'Star_rating': 'Three',
#   'Title': 'The Complete Maus (Maus #1-2)',
#   '_id': ObjectId('6495541fa0480a0e669ef995')}
# { 'Price': 14.76,
#   'Star_rating': 'Three',
#   'Title': 'The Communist Manifesto',
#   '_id': ObjectId('6495541fa0480a0e669ef996')}
# { 'Price': 57.49,
#   'Star_rating': 'Three',
#   'Title': 'The Bhagavad Gita',
#   '_id': ObjectId('6495541fa0480a0e669ef997')}
# { 'Price': 30.66,
#   'Star_rating': 'Three',
#   'Title': 'The Bette Davis Club',
#   '_id': ObjectId('6495541fa0480a0e669ef998')}
# { 'Price': 40.83,
#   'Star_rating': 'Four',
#   'Title': 'The Art of Not Breathing',
#   '_id': ObjectId('6495541fa0480a0e669ef999')}
# { 'Price': 18.88,
#   'Star_rating': 'Two',
#   'Title': 'Taking Shots (Assassins #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef99a')}
# { 'Price': 25.83,
#   'Star_rating': 'Three',
#   'Title': 'Starlark',
#   '_id': ObjectId('6495541fa0480a0e669ef99b')}
# { 'Price': 42.12,
#   'Star_rating': 'Three',
#   'Title': 'Skip Beat!, Vol. 01 (Skip Beat! #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef99c')}
# { 'Price': 13.33,
#   'Star_rating': 'Three',
#   'Title': 'Sister Sable (The Mad Queen #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef99d')}
# { 'Price': 42.4,
#   'Star_rating': 'One',
#   'Title': 'Shatter Me (Shatter Me #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef99e')}
# { 'Price': 58.35,
#   'Star_rating': 'Three',
#   'Title': 'Shameless',
#   '_id': ObjectId('6495541fa0480a0e669ef99f')}
# { 'Price': 21.72,
#   'Star_rating': 'Four',
#   'Title': 'Shadow Rites (Jane Yellowrock #10)',
#   '_id': ObjectId('6495541fa0480a0e669ef9a0')}
# { 'Price': 44.91,
#   'Star_rating': 'Two',
#   'Title': 'Settling the Score (The Summer Games #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef9a1')}
# { 'Price': 37.46,
#   'Star_rating': 'One',
#   'Title': 'Sense and Sensibility',
#   '_id': ObjectId('6495541fa0480a0e669ef9a2')}
# { 'Price': 28.48,
#   'Star_rating': 'One',
#   'Title': 'Saga, Volume 1 (Saga (Collected Editions) #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef9a3')}
# { 'Price': 28.34,
#   'Star_rating': 'Two',
#   'Title': 'Rhythm, Chord & Malykhin',
#   '_id': ObjectId('6495541fa0480a0e669ef9a4')}
# { 'Price': 46.96,
#   'Star_rating': 'Five',
#   'Title': 'Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected '
#            'Editions) #1-5)',
#   '_id': ObjectId('6495541fa0480a0e669ef9a5')}
# { 'Price': 24.96,
#   'Star_rating': 'One',
#   'Title': 'Paradise Lost (Paradise #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef9a6')}
# { 'Price': 21.71,
#   'Star_rating': 'Four',
#   'Title': 'Paper Girls, Vol. 1 (Paper Girls #1-5)',
#   '_id': ObjectId('6495541fa0480a0e669ef9a7')}
# { 'Price': 29.87,
#   'Star_rating': 'Three',
#   'Title': 'Ouran High School Host Club, Vol. 1 (Ouran High School Host Club '
#            '#1)',
#   '_id': ObjectId('6495541fa0480a0e669ef9a8')}
# { 'Price': 28.99,
#   'Star_rating': 'One',
#   'Title': 'Origins (Alphas 0.5)',
#   '_id': ObjectId('6495541fa0480a0e669ef9a9')}
# { 'Price': 52.94,
#   'Star_rating': 'Two',
#   'Title': 'One Second (Seven #7)',
#   '_id': ObjectId('6495541fa0480a0e669ef9aa')}
# { 'Price': 32.36,
#   'Star_rating': 'Three',
#   'Title': 'On the Road (Duluoz Legend)',
#   '_id': ObjectId('6495541fa0480a0e669ef9ab')}
# { 'Price': 55.66,
#   'Star_rating': 'Two',
#   'Title': "Old Records Never Die: One Man's Quest for His Vinyl and His Past",
#   '_id': ObjectId('6495541fa0480a0e669ef9ac')}
# { 'Price': 39.45,
#   'Star_rating': 'Five',
#   'Title': 'Off Sides (Off #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef9ad')}
# { 'Price': 47.11,
#   'Star_rating': 'Two',
#   'Title': 'Of Mice and Men',
#   '_id': ObjectId('6495541fa0480a0e669ef9ae')}
# { 'Price': 58.75,
#   'Star_rating': 'Four',
#   'Title': 'Myriad (Prentor #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef9af')}
# { 'Price': 38.92,
#   'Star_rating': 'Two',
#   'Title': 'My Perfect Mistake (Over the Top #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef9b0')}
# { 'Price': 39.39,
#   'Star_rating': 'Four',
#   'Title': 'Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef9b1')}
# { 'Price': 25.89,
#   'Star_rating': 'Two',
#   'Title': 'Meditations',
#   '_id': ObjectId('6495541fa0480a0e669ef9b2')}
# { 'Price': 28.34,
#   'Star_rating': 'One',
#   'Title': 'Matilda',
#   '_id': ObjectId('6495541fa0480a0e669ef9b3')}
# { 'Price': 27.7,
#   'Star_rating': 'Four',
#   'Title': 'Lost Among the Living',
#   '_id': ObjectId('6495541fa0480a0e669ef9b4')}
# { 'Price': 24.89,
#   'Star_rating': 'Three',
#   'Title': 'Lord of the Flies',
#   '_id': ObjectId('6495541fa0480a0e669ef9b5')}
# { 'Price': 58.99,
#   'Star_rating': 'Three',
#   'Title': 'Listen to Me (Fusion #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef9b6')}
# { 'Price': 57.2,
#   'Star_rating': 'Five',
#   'Title': 'Kitchens of the Great Midwest',
#   '_id': ObjectId('6495541fa0480a0e669ef9b7')}
# { 'Price': 38.43,
#   'Star_rating': 'Five',
#   'Title': 'Jane Eyre',
#   '_id': ObjectId('6495541fa0480a0e669ef9b8')}
# { 'Price': 34.74,
#   'Star_rating': 'Four',
#   'Title': 'Imperfect Harmony',
#   '_id': ObjectId('6495541fa0480a0e669ef9b9')}
# { 'Price': 40.44,
#   'Star_rating': 'Four',
#   'Title': 'Icing (Aces Hockey #2)',
#   '_id': ObjectId('6495541fa0480a0e669ef9ba')}
# { 'Price': 45.24,
#   'Star_rating': 'Three',
#   'Title': 'Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef9bb')}
# { 'Price': 34.96,
#   'Star_rating': 'Four',
#   'Title': "Having the Barbarian's Baby (Ice Planet Barbarians #7.5)",
#   '_id': ObjectId('6495541fa0480a0e669ef9bc')}
# { 'Price': 56.76,
#   'Star_rating': 'Four',
#   'Title': 'Giant Days, Vol. 1 (Giant Days #1-4)',
#   '_id': ObjectId('6495541fa0480a0e669ef9bd')}
# { 'Price': 40.28,
#   'Star_rating': 'Five',
#   'Title': 'Fruits Basket, Vol. 1 (Fruits Basket #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef9be')}
# { 'Price': 38.0,
#   'Star_rating': 'Two',
#   'Title': 'Frankenstein',
#   '_id': ObjectId('6495541fa0480a0e669ef9bf')}
# { 'Price': 28.8,
#   'Star_rating': 'Three',
#   'Title': 'Forever Rockers (The Rocker #12)',
#   '_id': ObjectId('6495541fa0480a0e669ef9c0')}
# { 'Price': 39.24,
#   'Star_rating': 'Three',
#   'Title': 'Fighting Fate (Fighting #6)',
#   '_id': ObjectId('6495541fa0480a0e669ef9c1')}
# { 'Price': 32.93,
#   'Star_rating': 'Two',
#   'Title': 'Emma',
#   '_id': ObjectId('6495541fa0480a0e669ef9c2')}
# { 'Price': 51.32,
#   'Star_rating': 'Three',
#   'Title': 'Eat, Pray, Love',
#   '_id': ObjectId('6495541fa0480a0e669ef9c3')}
# { 'Price': 47.09,
#   'Star_rating': 'Five',
#   'Title': 'Deep Under (Walker Security #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef9c4')}
# { 'Price': 28.42,
#   'Star_rating': 'Four',
#   'Title': "Choosing Our Religion: The Spiritual Lives of America's Nones",
#   '_id': ObjectId('6495541fa0480a0e669ef9c5')}
# { 'Price': 22.85,
#   'Star_rating': 'Three',
#   'Title': 'Charlie and the Chocolate Factory (Charlie Bucket #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef9c6')}
# { 'Price': 41.24,
#   'Star_rating': 'One',
#   'Title': "Charity's Cross (Charles Towne Belles #4)",
#   '_id': ObjectId('6495541fa0480a0e669ef9c7')}
# { 'Price': 39.07,
#   'Star_rating': 'Five',
#   'Title': 'Bright Lines',
#   '_id': ObjectId('6495541fa0480a0e669ef9c8')}
# { 'Price': 29.82,
#   'Star_rating': 'One',
#   'Title': "Bridget Jones's Diary (Bridget Jones #1)",
#   '_id': ObjectId('6495541fa0480a0e669ef9c9')}
# { 'Price': 37.26,
#   'Star_rating': 'Four',
#   'Title': 'Bounty (Colorado Mountain #7)',
#   '_id': ObjectId('6495541fa0480a0e669ef9ca')}
# { 'Price': 20.3,
#   'Star_rating': 'Three',
#   'Title': 'Blood Defense (Samantha Brinkman #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef9cb')}
# { 'Price': 34.65,
#   'Star_rating': 'Five',
#   'Title': 'Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef9cc')}
# { 'Price': 43.38,
#   'Star_rating': 'One',
#   'Title': 'Beyond Good and Evil',
#   '_id': ObjectId('6495541fa0480a0e669ef9cd')}
# { 'Price': 55.53,
#   'Star_rating': 'One',
#   'Title': "Alice in Wonderland (Alice's Adventures in Wonderland #1)",
#   '_id': ObjectId('6495541fa0480a0e669ef9ce')}
# { 'Price': 57.06,
#   'Star_rating': 'Four',
#   'Title': 'Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)',
#   '_id': ObjectId('6495541fa0480a0e669ef9cf')}
# { 'Price': 16.97,
#   'Star_rating': 'Five',
#   'Title': "A Spy's Devotion (The Regency Spies of London #1)",
#   '_id': ObjectId('6495541fa0480a0e669ef9d0')}
# { 'Price': 53.98,
#   'Star_rating': 'One',
#   'Title': "1st to Die (Women's Murder Club #1)",
#   '_id': ObjectId('6495541fa0480a0e669ef9d1')}
# { 'Price': 26.08,
#   'Star_rating': 'Five',
#   'Title': '1,000 Places to See Before You Die',
#   '_id': ObjectId('6495541fa0480a0e669ef9d2')}

# %% [markdown]
# **COMMENT:**
# Notice how prettier the output showing our records is on printing it out with PrettyPrinter

# %% [markdown]
# ### Let's convert our data from dictionary format into a DataFrame:

# %%
#let's create another cursor object having exhausted the previous one with our for loop.
all_records = mycollection.find({})

# %%
#let's pass all_records into a list
list_all_records = list(all_records)

# %%
books_df = pd.DataFrame(list_all_records)
books_df.head()
# Out:
#                         _id                                  Title  Price  \
# 0  6495541fa0480a0e669ef5eb                   A Light in the Attic  51.77
# 1  6495541fa0480a0e669ef5ec                     Tipping the Velvet  53.74
# 2  6495541fa0480a0e669ef5ed                             Soumission  50.10
# 3  6495541fa0480a0e669ef5ee                          Sharp Objects  47.82
# 4  6495541fa0480a0e669ef5ef  Sapiens: A Brief History of Humankind  54.23
#
#   Star_rating
# 0       Three
# 1         One
# 2         One
# 3        Four
# 4        Five

# %%
books_df.tail()
# Out:
#                           _id  \
# 995  6495541fa0480a0e669ef9ce
# 996  6495541fa0480a0e669ef9cf
# 997  6495541fa0480a0e669ef9d0
# 998  6495541fa0480a0e669ef9d1
# 999  6495541fa0480a0e669ef9d2
#
#                                                  Title  Price Star_rating
# 995  Alice in Wonderland (Alice's Adventures in Won...  55.53         One
# 996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)  57.06        Four
# 997  A Spy's Devotion (The Regency Spies of London #1)  16.97        Five
# 998                1st to Die (Women's Murder Club #1)  53.98         One
# 999                 1,000 Places to See Before You Die  26.08        Five

# %%
books_df.shape
# Out:
# (1000, 4)

# %% [markdown]
# **COMMENT:**
# We now have 1000 row and 4 columns of dataset, however, one can easily drop the _id column.

# %% [markdown]
# **The End. Thank you!!!**
